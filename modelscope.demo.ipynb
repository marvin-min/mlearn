# %% [markdown]
# 模型: Ceceliachenen/bge-large-zh-v1.5

# %%
from langchain_core.prompts import PromptTemplate
from modelscope import snapshot_download

from 提示词模板 import template

model_dir = snapshot_download("Ceceliachenen/bge-large-zh-v1.5", cache_dir="/Users/marvin/workspace/ml/model/BAAI/bge-large-zh-v1.5")
# Out:
# ...
# 2025-10-25 22:51:24,103 - modelscope - INFO - Got 12 files, start to download ...
# Processing 12 items:   0%|          | 0.00/12.0 [00:00<?, ?it/s]
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
# ...
#
# ...
#
#
#
# ...
#
# Processing 12 items:   8%|▊         | 1.00/12.0 [00:00<00:04, 2.48it/s]:00, 497B/s]
#
# ...
#
#
# ...
#
# ...
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
# ...
#
#
#
# ...
#
#
#
#
# ...
#
#
#
#
# ...
# Processing 12 items:  58%|█████▊    | 7.00/12.0 [00:00<00:00, 17.4it/s]
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
# ...
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
#
# ...
#
#
#
# ...
#
#
#
#
#
# ...
# Processing 12 items:  92%|█████████▏| 11.0/12.0 [00:01<00:00, 9.33it/s]
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
model_name = r"/Users/marvin/workspace/ml/model/BAAI/bge-large-zh-v1.5/Ceceliachenen/bge-large-zh-v1___5"

# %%
encode_kwargs={'normalize_embeddings':True}
embeddings = HuggingFaceBgeEmbeddings(
  model_name=model_name,
  encode_kwargs=encode_kwargs,
)

text = "大模型"
doc_result = embeddings.embed_documents([text])
print(doc_result[0][:5])
doc_result = embeddings.embed_query(text)
print(doc_result[:5])
# Out:
# [0.007317071780562401, 0.018718602135777473, -0.015059947036206722, 0.05245792493224144, -0.011361428536474705]
# [-0.01573960669338703, 0.027081888169050217, -0.014799339696764946, 0.05025268346071243, 0.01867886632680893]

# %%
from langchain_openai import ChatOpenAI
import os
llm = ChatOpenAI(model="Qwen/Qwen2.5-72B-Instruct", api_key=os.getenv("SILICON_API_KEY"), base_url=os.getenv("SILICON_BASE_URL"))

# %%
from langchain_core.prompts import PromptTemplate
template = "桌子上有{number}个苹果，四个桃子和3本书，一共有几个水果？"
prompt = PromptTemplate.from_template(template)
chain = prompt | llm

# %%
result = chain.invoke({"number": 3})
print(result)
